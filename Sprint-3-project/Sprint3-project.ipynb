# %% [markdown]
# Olá, Raimir
#
# Meu nome é Ramon. Ao ao longo do texto farei algumas observações sobre melhorias no código. Nas partes em que não houver comentários, está tudo certo, ok? Estarei aberto a feedbacks e discussões sobre o tema.
#
# **Peço que mantenha e não altere os comentários que eu fizer por aqui para que possamos nos localizar posteriormente, ok?**
#
# Mais uma coisa, vamos utilizar um código de cores para você entender os meus feedbacks no seu notebook. Funciona assim:
#
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo foi feito corretamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Alerta não crítco, mas que pode ser corrigido para melhoria geral no seu código/análise
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Erro que precisa ser consertado, caso contrário seu projeto **não** será aceito.
# </div>
#
# Você pode me responder usando isso:
# <div class="alert alert-block alert-info">
# <b>Resposta do Aluno.</b> <a class="tocSkip"></a>
# </div>
#
# ###
#
# <div class="alert alert-block alert-success">
# <b>Comentário Geral do Revisor</b> <a class="tocSkip"></a>
#
# Obrigado por enviar seu projeto.
#
# Parabéns, você fez um bom trabalho.
#
# Como pontos fortes do projeto, destaco:
# - Código simples e eficiente (sem loop desnecessário)
# - Uso adequado dos recursos da lição
# - Boa lógica de programação, pois acertou as mais difíceis
#
# <span class="text-danger">Porém, há espaço para melhorias: </span>
#  * <span class="text-danger"> pequenos ajustes quanto ao uso de funções e um pequeno erro de lógica </span>
#
#
# Portanto, sugiro que você corrija os pontos indicados.
#
# Se você tiver alguma dúvida sobre de algo que você não tenha entendido, sinta-se à vontade para perguntar ao tutor ou deixar um comentário em **azul** para que, na próxima iteração, eu possa responder.
#
# Conte conosco. Lembre-se de que você pode tirar dúvidas com revisores usando os comentários ou buscar ajuda de um tutor.
# Bom trabalho.
#
#
# </div>

# %% [markdown]
# # Vamos encher o carrinho!

# %% [markdown]
# # Introdução
#
# O Instacart é uma plataforma de entrega de supermercado onde os clientes podem fazer um pedido no supermercado e depois receber sua compra, semelhante ao funcionamento do Uber Eats e do iFood. O conjunto de dados que fornecemos foi modificado a partir do original. Reduzimos o tamanho dele para que seus cálculos sejam executados mais rapidamente e incluímos valores ausentes e duplicados. Também tivemos o cuidado de preservar as distribuições dos dados originais quando fizemos as alterações.
#
# Você precisa completar três etapas. Para cada uma delas, escreva uma breve introdução descrevendo como você pretende concluir a etapa e justifique suas decisões em parágrafos explicativos a medida que você avança na solução. Escreva também uma conclusão para resumir suas conclusões e escolhas.

# %% [markdown]
# ## Dicionário de dados
#
# Há cinco tabelas no conjunto de dados, e você vai precisar usar todas elas para pré-processar seus dados e fazer AED. Abaixo está um dicionário que lista as colunas de cada tabela e descreve os dados contidos nelas.
#
# - `instacart_orders.csv`: cada linha corresponde a um pedido no aplicativo da Instacart
#     - `'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     - `'user_id'`: é o número de identificação exclusivo da conta de cada cliente
#     - `'order_number'`: é o número de vezes que o cliente fez um pedido
#     - `'order_dow'`: é o dia da semana em que o pedido foi feito (0 é domingo)
#     - `'order_hour_of_day'`: é a hora do dia em que o pedido foi feito
#     - `'days_since_prior_order'`: é o número de dias desde que o cliente fez seu pedido anterior
#
#
#
#
# - `products.csv`: cada linha corresponde a um produto exclusivo que os clientes podem comprar
#     - `'product_id'`: é o número de identificação unívoco de cada produto
#     - `'product_name'`: é o nome do produto
#     - `'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     - `'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#
#
#
#
# -	`order_products.csv`: cada linha corresponde a um item incluído em um pedido
#     -	`'order_id'`: é o número que identifica cada pedido de forma exclusiva
#     -	`'product_id'`: é o número de identificação exclusivo de cada produto
#     -	`'add_to_cart_order'`: é a ordem sequencial em que cada item foi colocado no carrinho
#     -	`'reordered'`: 0 se o cliente nunca comprou o produto antes, 1 se já o comprou
#
#
#
#
# -	`aisles.csv`
#     -	`'aisle_id'`: é o número de identificação exclusivo de cada categoria de corredor do supermercado
#     -	`'aisle'`: é o nome do corredor
#
#
#
# -	`departments.csv`
#     -	`'department_id'`: é o número de identificação exclusivo de cada categoria de departamento do supermercado
#     -	`'department'`: é o nome do departamento

# %% [markdown]
# # Etapa 1. Visão geral dos dados
#
# Leia os arquivos de dados (/datasets/instacart_orders.csv, /datasets/products.csv, /datasets/aisles.csv, /datasets/departments.csv e /datasets/order_products.csv) com `pd.read_csv()` usando os parâmetros apropriados para fazer isso corretamente. Verifique as informações para cada DataFrame criado.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Visão geral dos dados
#
# ***Executar leitura e visualização dos dfs***

# %%
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np
# Importe as bibliotecas

# %%
df_orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
df_departments = pd.read_csv('/datasets/departments.csv', sep=';')
df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')
# leia os conjuntos de dados em DataFrames

# %%
display(df_orders)
print()
df_orders.info(show_counts=True)
# imprima as informações sobre o DataFrame
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        1515936   183418            11          6                 13
# 1        1690866   163593             5          5                 12
# 2        1454967    39980             4          5                 19
# 3        1768857    82516            56          0                 20
# 4        3007858   196724             2          4                 12
# ...          ...      ...           ...        ...                ...
# 478962   3210681     5617             5          1                 14
# 478963   3270802   112087             2          3                 13
# 478964    885349    82944            16          2                 11
# 478965    216274     4391             3          3                  8
# 478966   2071924     1730            18          1                 14
#
#         days_since_prior_order
# 0                         30.0
# 1                          9.0
# ...

# %%
display(df_products)
print()
df_products.info(show_counts=True)
# imprima as informações sobre o DataFrame
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
display(df_aisles)
print()
df_aisles.info(show_counts=True)
# imprima as informações sobre o DataFrame
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
display(df_departments)
print()
df_departments.info(show_counts=True)
# imprima as informações sobre o DataFrame
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ...

# %%
display(df_order_products)
print()
df_order_products.info(show_counts=True)
# imprima as informações sobre o DataFrame
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
# ...

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 1. Visão geral dos dados
#
# **df_orders:**
#
# *alores ausentes apenas na coluna float, sep=';', dtypes: int (5 colunas), float (1 coluna).
# a coluna com dados float representa quantidade de dias então provável não haver perda de informações quando transformar em int (checar com np.array_equal()).*
#
#
# **df_products:**
#
# *Valores ausentes apenas na coluna object, sep=';', dtypes: int (3 colunas), object (1 coluna).
# a coluna com dados object representa nomes dos produtos em letras maiúsculas, minúsculas e símbolos.*
#
#
# **df_aisles:**
#
# *Sem valores ausentes, sep=';', dtypes: int (1 coluna), object (1 coluna).*
#
#
# **df_departments:**
#
# *Sem valores ausentes, sep=';', dtypes: int (1 coluna), object (1 coluna) e todos os valores com letras minúsculas.*
#
#
# **df_order_products:**
#
# *Valores ausentes apenas na coluna float, sep=';', dtypes: int (3 colunas), float (1 coluna).
# a coluna com dados float representa a ordem sequencial em que cada item foi colocado no carrinho então provável não haver perda de informações quando transformar em int (checar com np.array_equal()).*

# %% [markdown]
# # Etapa 2. Preparação de dados
#
# Faça o pré-processamento dos dados da seguinte maneira:
#
# -	Verifique e corrija os tipos de dados (por exemplo, certifique-se de que as colunas de ID sejam números inteiros)
# -	Identifique e preencha valores ausentes
# -	Identifique e remova valores duplicados
#
# Certifique-se de explicar que tipos de valores ausentes e duplicados você encontrou, como você os preencheu ou removeu, por que escolheu esses métodos e por que você acha que esses valores ausentes e duplicados estavam presentes no conjunto de dados.

# %% [markdown]
# ## Plano de solução
#
# Escreva aqui seu plano para a Etapa 2. Preparação de dados
#
# ***Tratar os dados conforme solicitações***

# %% [markdown]
# ## Encontre e remova valores duplicados (e descreva por que você está fazendo suas escolhas)

# %% [markdown]
# ### DataFrame `instacart_orders`

# %%
print(df_orders.duplicated().sum())
print()
display(df_orders[df_orders.duplicated()])
print()
display(df_orders['order_id'].nunique())
print()
df_orders.info(show_counts=True)
# Verificar se há pedidos duplicados
# Out:
# 15
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# Há linhas duplicadas? Se sim, o que elas têm em comum?
#
# _**Sim, temos o retorno de 15 linhas duplicadas. Porém o que elas têm em comum são os dias da semana e a hora da compra, o que é normal, pois não teríamos apenas uma compra por dia. Logo, essas linhas não trazem informações duplicadas que devam ser descartadas.**_
#
# _**Conforme verificado com nunique(), cada pedido tem um identificador único, o que significa que são pedidos genuinamente diferentes**_

# %%
# Com base nas suas conclusões,

# verifique todos os pedidos feitos às 2h da manhã nas quartas-feiras

wednesday_2am_orders = df_orders[(df_orders['order_hour_of_day'] == 2) & (df_orders['order_dow'] == 3)]

print(len(wednesday_2am_orders))
print()
display(wednesday_2am_orders.head(15))
# Out:
# 121
#        order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838    2766110   162084            41          3                  2
# 5156    2190225   138285            18          3                  2
# 15506    553049    58599            13          3                  2
# 18420    382357   120200            19          3                  2
# 24691    690242    77357             2          3                  2
# 25376   1378085    75705            21          3                  2
# 26301   2846262   176827             2          3                  2
# 29129    353088    46038             4          3                  2
# 30371   1918001   188546            14          3                  2
# 31404   1725788   147843            10          3                  2
# 48024   1453300    69262            27          3                  2
# 52245   2851380   118608            33          3                  2
# ...

# %% [markdown]
# O que esse resultado quer dizer?
#
# _**Esse resultado quer dizer que 121 pedidos foram realizados no dia e horário filtrados.**_

# %%
# Remova pedidos duplicados
df_orders_wo_dupl = df_orders.drop_duplicates()

# %%
# Verifique as linhas duplicadas mais uma vez
print(f"Antes: {len(df_orders)} linhas")
print(f"Depois: {len(df_orders_wo_dupl)} linhas")
# Out:
# Antes: 478967 linhas
# Depois: 478952 linhas

# %%
# Verifique novamente apenas os IDs de pedidos duplicados
# A ideia aqui é verificar apenas os IDs das 15 linhas duplicadas ou 
# verificar se após a remoção de duplicados agora temos apenas valores unívocos na coluna?
# Ficou ambíguo para mim e optei pela segunda opção

print('Total de linhas:', len(df_orders_wo_dupl))
print("IDs únicos:", df_orders_wo_dupl['order_id'].nunique())
# Out:
# Total de linhas: 478952
# IDs únicos: 478952

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Concluí que independente de os dados duplicados serem realmente duplicados ou não, pela quantidade de dados total, a exclusão não faria diferença na análise. Isto posto, filtrei para visualizar a quantidade de pedidos feitos no mesmo dia e horário solicitados, excluí linhas duplicadas e confirmei a exclusão verificando a quantidade de linhas e a quantidade de valores únicos.***

# %% [markdown]
# ### DataFrame `products`

# %%
# Verifique se há linhas completamente duplicadas
print(df_products.duplicated().sum())
print(df_products.nunique())
# Out:
# 0
# product_id       49694
# product_name     48436
# aisle_id           134
# department_id       21
# dtype: int64

# %%
# Verifique apenas IDs dos produtos duplicados
print(df_products['product_id'].duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas nomes de produtos duplicados (converta os nomes para minúsculas para uma comparação melhor)
df_products_lowered = df_products['product_name'].str.lower().duplicated().sum()
print(df_products_lowered)
# Out:
# 1361

# %%
# Verifique os nomes de produtos duplicados que não estão faltando
df_products_low_drp = df_products['product_name'].dropna().str.lower().duplicated().sum()
print(df_products_low_drp)
# Out:
# 104

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Não há linhas completamente duplicadas, verificado através de duplicated().***
#
# ***Idem para a coluna product_id.***
#
# ***Após a conversão dos nomes para minúsculas na coluna product_name, foram verificados 1361 itens duplicados (podendo conter valores NaN).***
#
# ***Excluídos valores NaN através de dropna().***

# %% [markdown]
# ### DataFrame `departments`

# %%
# Verifique se há linhas completamente duplicadas
print(df_departments.duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
print(df_departments['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Sem quaisquer dados duplicados***

# %% [markdown]
# ### DataFrame `aisles`

# %%
# Verifique se há linhas completamente duplicadas
print(df_aisles.duplicated().sum())
# Out:
# 0

# %%
# Verifique apenas se há IDs dos produtos duplicados
print(df_aisles['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Sem quaisquer dados duplicados***

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Verifique se há linhas completamente duplicadas
print(df_order_products.duplicated().sum())
# Out:
# 0

# %%
# Verifique mais uma vez se há outros casos complicados de duplicados
print(df_order_products['order_id'].duplicated().sum())
print()
print(df_order_products['order_id'].nunique())
print()
df_order_products.info(show_counts=True)
# Out:
# 4094961
#
# 450046
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Se em order_products.csv, cada linha corresponde a um item incluído em um pedido, order_id e product_id aparecerão várias vezes, teremos duplicados, mas a informação não é duplicada.***

# %% [markdown]
# ## Encontre e remova valores ausentes
#
#
# Ao processarmos valores duplicados, observamos que também temos valores ausentes que precisamos investigar nas seguintes colunas:
#
# *	A coluna `'product_name'` da tabela products.
# *	A coluna `'days_since_prior_order'` da tabela orders.
# *	A coluna `'add_to_cart_order'` da tabela order_products.

# %% [markdown]
# ### DataFrame `products`

# %%
# Encontre valores ausentes na coluna 'product_name'
display(df_products[df_products['product_name'].isna()])
print()
print(df_products[df_products['product_name'].isna()].count())
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]
# product_id       1258
# product_name        0
# aisle_id         1258
# department_id    1258
# dtype: int64

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# ***Apliquei o filtro com isna() que me retornou apenas as 1.258 linhas onde product_name é NaN. Com a utilização de count(), tive retorno da quantidade de valores não-nulos em cada coluna onde o valor de product_name é NaN.***
#
# ***A coluna product_name retornou zero, devido ao filtro (filtrei apenas linhas de product_name = NaN)***
#
# ***Conclui-se que mesmo quando o nome do produto está ausente, as outras informações (ID, corredor e departamento) estão completas.***

# %%
# Todos os nomes de produtos ausentes estão associados com o corredor de ID 100?
products_wo_names = df_products[df_products['product_name'].isna()]
print(products_wo_names['aisle_id'].unique())
# Out:
# [100]

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# ***Num primeiro momento filtrei produtos sem nome da coluna product_name e em seguida relacionei com a coluna aisle_id. De forma que me retornasse o seguinte: dentre os valores NaN da coluna product_name, quais constam também em aisle_id (para isso usei unique()).***

# %%
# Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?
products_wo_names = df_products[df_products['product_name'].isna()]
print(products_wo_names['department_id'].unique())
# Out:
# [21]

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# *Todos os nomes de produtos ausentes estão associados com o departamento de ID 21?*
# ***Sim. Utilizei o mesmo raciocínio da questão anterior.***

# %%
# Use as tabelas department e aisle para verificar os dados do corredor com ID 100 e do departamento com ID 21.
aisle_100 = df_aisles[df_aisles['aisle_id'] == 100]
print("Aisle ID 100:")
display(aisle_100)
print()
department_21 = df_departments[df_departments['department_id'] == 21]
print("Department ID 21:")
display(department_21)
# Out:
# Aisle ID 100:
#     aisle_id    aisle
# 99       100  missing
# Department ID 21:
#     department_id department
# 20             21    missing

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# ***Ao consultar as tabelas vi que o valor do corredor 100 é 'missing', assim como o valor do departamento 21. Ficou claro que o valor "missing" é exatamente como um NaN ou None, mas representado como texto (não possuem nome definido).***
#
# ***É possível concluir que trata-se de produtos que não foram categorizados corretamente.***

# %%
# Preencha nomes de produtos ausentes com 'Unknown'
# df_products_wo_nan = df_products['product_name'].replace(np.nan, 'Unknown')
df_products_wo_nan = df_products['product_name'].fillna('Unknown')
print(df_products_wo_nan.isna().any())
# Out:
# False

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor v1: </b> <a class="tocSkip"></a>
#
# - o ideal é usar .fillna()
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Blz, adicionei ao código.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor V2: </b> <a class="tocSkip"></a>
#
# Correto
# </div>

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Valores ausentes substituídos através do método .replace() e conferência realizada .isna().any(), que me retornou false, confirmando que não há valores NaN ou None.***

# %% [markdown]
# ### DataFrame `orders`

# %%
# Encontre os valores ausentes
print(df_orders.isna().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28819
# dtype: int64

# %%
# Há valores ausentes para os clientes que não estão fazendo o primeiro pedido?
df_orders_wo_day = df_orders[df_orders['days_since_prior_order'].isna()]
print(df_orders_wo_day['order_number'].value_counts())
# Out:
# 1    28819
# Name: order_number, dtype: int64

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***Através da relação entre a filtragem de valores ausentes na coluna days_since_prior_order e a contagem de quantas vzs order_number aparece no filtro aplicado, conclui-se que todos os pedidos com valores ausentes têm order_number = 1 e que a quantidade desses pedidos é a mesma da quantidade total de pedidos com valores ausentes.***

# %% [markdown]
# ### DataFrame `order_products`

# %%
# Encontre os valores ausentes
print(df_order_products.isna().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# Quais são os valores mínimo e máximo dessa coluna?
display(df_order_products.describe())
print()
print('O valor máximo é:', df_order_products['add_to_cart_order'].max())
print()
print('O valor mínimo é:', df_order_products['add_to_cart_order'].min())
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00
# O valor máximo é: 64.0
#
# O valor mínimo é: 1.0

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# ***Usei o display() apenas para visualizar como seria exibido mín() e máx() através de describe(). Para extrair os valores mín e máx bastava fazer o que fiz em seguida.***

# %%
# Salve todos os IDs dos pedidos com pelo menos um valor ausente em 'add_to_cart_order'
df_order_products_nan = df_order_products[df_order_products['add_to_cart_order'].isna()]
order_id_nan = df_order_products_nan['order_id'].unique()
print('Quantidade de pedidos com valores ausentes:', len(order_id_nan))
# Out:
# Quantidade de pedidos com valores ausentes: 70

# %%
# Todos os pedidos com valores ausentes contêm mais de 64 produtos?
# Agrupe os pedidos com dados ausentes por ID de pedido
# Conte o número de 'product_id' em cada pedido e verifique o valor mínimo da contagem

# %%
miss_cart_order_ids = sorted(list(df_order_products_nan['order_id'].unique()))
products_per_order = df_order_products[df_order_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id').size().sort_values()
print('Contagem de produtos por pedido:')
print(products_per_order.reset_index(name='products_quantity'))
print()
print('Valor mínimo da contagem:', products_per_order.min())
# Out:
# Contagem de produtos por pedido:
#     order_id  products_quantity
# 0       9310                 65
# 1     747668                 65
# 2    1598369                 65
# 3    1677118                 65
# 4    2170451                 65
# ..       ...                ...
# 65   1959075                 98
# 66    171934                104
# 67   2136777                108
# 68   3308010                115
# 69     61355                127
#
# [70 rows x 2 columns]
#
# Valor mínimo da contagem: 65

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor v1: </b> <a class="tocSkip"></a>
#
# - erro de lógica. deixo dica
#
# </div>

# %%
# miss_cart_order_ids = sorted(list(order_products[order_products['add_to_cart_order'].isna()]['order_id'].unique()))
# order_products[order_products['order_id'].isin(miss_cart_order_ids)].groupby('order_id').size().sort_values()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Refiz.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor V2: </b> <a class="tocSkip"></a>
#
# Correto
# </div>

# %% [markdown]
# Descreva brevemente suas conclusões.
#
# ***Dos 836 valores ausentes em add_to_cart_order, apenas 70 referem-se a pedidos únicos diferentes, ou seja, alguns pedidos têm múltiplos produtos com valores ausentes em add_to_cart_order.***
#
# ***Vimos que há 836 valores ausentes na coluna 'add_to_cart_order' que estão distribuídos em apenas 70 pedidos únicos. A hipótese é que quando um pedido tem mais de 64 produtos, o sistema pode não conseguir registrar a ordem de adição ao carrinho para todos os itens, resultando em valores ausentes.***
#
# ***Após a última verificação conclui-se que a hipótese procede, uma vez que o valor mínimo encontrado em pedidos com produtos ausentes foi de 65 produtos.***

# %%
# Substitua valores ausentes na coluna 'add_to_cart_order' por 999 e converta a coluna para o tipo integer
df_order_products_wo_nan = df_order_products['add_to_cart_order'].replace(np.nan, 999).astype('int')
print('Há valores NaN?', df_order_products_wo_nan.isna().any())
print()
print('Quantidade de valores NaN:', df_order_products_wo_nan.isna().sum())
# Out:
# Há valores NaN? False
#
# Quantidade de valores NaN: 0

# %% [markdown]
# Descreva brevemente suas conclusões e o que você fez com elas.
#
# ***A conversão é óbvia, pois não ocorrerá perda de informações.***
#
# ***Utilizei 2 métodos para confirmar que a substituição foi realizada corretamente.***

# %% [markdown]
# ## Conclusões
#
# Escreva aqui suas conclusões intermediárias da Etapa 2. Preparação de dados
#
# ***Os dados foram tratados e estão prontos para análise. O passa a passo sobre o que fiz e como fiz foi colocado após cada tarefa.***

# %% [markdown]
# # Etapa 3. Análise de dados
#
# Quando os dados estiverem processados ​​e prontos, execute a seguinte análise:

# %% [markdown]
# # [A] Fácil (é necessário concluir tudo para passar)
#
# 1.	Verifique se os valores nas colunas `'order_hour_of_day'` e `'order_dow'` na tabela `orders` fazem sentido (ou seja, os valores da coluna  `'order_hour_of_day'` variam de 0 a 23 e os da `'order_dow'` variam de 0 a 6).
# 2.	Crie um gráfico que mostre quantas pessoas fazem pedidos a cada hora do dia.
# 3.	Crie um gráfico que mostre em que dia da semana as pessoas fazem compras.
# 4.	Crie um gráfico que mostre quanto tempo as pessoas esperam até fazer seu próximo pedido e comente sobre os valores mínimo e máximo.

# %% [markdown]
# ### [A1] Verifique se os valores fazem sentido

# %%
print('O valor mínimo é:', df_orders['order_hour_of_day'].min())
print()
print('O valor máximo é:', df_orders['order_hour_of_day'].max())
print()
print(df_orders['order_hour_of_day'].unique())
# Out:
# O valor mínimo é: 0
#
# O valor máximo é: 23
#
# [13 12 19 20 11  8 18 15 16  9 22 10  0 14 17  1  7  6  2 21  3 23  5  4]

# %%
print('O valor mínimo é:', df_orders['order_dow'].min())
print()
print('O valor máximo é:', df_orders['order_dow'].max())
print()
print(df_orders['order_dow'].unique())
# Out:
# O valor mínimo é: 0
#
# O valor máximo é: 6
#
# [6 5 0 4 3 1 2]

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Sim, fazem sentido.***

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor v1: </b> <a class="tocSkip"></a>
#
# - avaliou apenas max e min. oriento usar .unique() para avaliar todos os valores
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Feito. Pensei apenas em mín e máx devido ao enunciado, mas entendo que .unique() deveria ser utilizado para conferência no fim.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor V2: </b> <a class="tocSkip"></a>
#
# Entendi seu ponto. Faz sentido
# </div>

# %% [markdown]
# ### [A2] Quantas pessoas fazem pedidos a cada hora do dia?

# %%
df_orders_per_hour = df_orders['order_hour_of_day'].value_counts().sort_index()

df_orders_per_hour.plot(x='order_hour_of_day', y='order_number', xlabel='Hour', ylabel='Numer of orders', kind='bar', title='Orders per hour')

plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Número de pedidos é maior entre 10 e 11h da manhã.***
#
# ***O uso de .value_counts() é para apontar quantas vezes cada hora aparece nos dados.***
#
# ***Como .value_counts() retorna os resultados ordenados por frequência (do maior para o menor), não por hora, usei .sort_index() para colocar na sequência cronológica (um gráfico de horas do dia, faz mais sentido).***

# %% [markdown]
# ### [A3] Em que dia da semana as pessoas compram produtos alimentícios?

# %%
df_orders_per_day = df_orders['order_dow'].value_counts().sort_index()

df_orders_per_day.plot(x='order_dow', y='order_number', xlabel='Day', ylabel='Numer of orders', kind='bar', title='Orders per day')

plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Mesmo raciocínio do anterior. Mostra que domingo e segunda-feira são os dias com mais pedidos feitos.***

# %% [markdown]
# ### [A4] Quanto tempo as pessoas esperam até fazer outro pedido?

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Primeiro, removi os valores NaN (que são os primeiros pedidos).***
#
# ***Analisei a coluna days_since_prior_order do DataFrame df_orders, que representa quantos dias se passaram desde o pedido anterior de cada cliente.***

# %%
days_between_orders = df_orders['days_since_prior_order'].dropna()

days_between_orders.plot(kind='hist', bins=30, xlabel='Days since prior order', ylabel='Number of orders', title='Days between orders', edgecolor='gray', linewidth=0.5)
plt.show()

print('Valor mínimo:', days_between_orders.min())
print(f"Valor máximo: {days_between_orders.max()} dias")
print(f"Valor médio: {days_between_orders.mean():.1f} dias")
# Out:
# Valor mínimo: 0.0
# Valor máximo: 30.0 dias
# Valor médio: 11.1 dias

# %% [markdown]
# # [B] Médio (é necessário concluir tudo para passar)
#
# 1.	Há alguma diferença nas distribuições de `'order_hour_of_day'` nas quartas e sábados? Construa gráficos de barras para ambos os dias no mesmo gráfico e descreva as diferenças que você notou.
# 2.	Construa um gráfico de distribuição para o número de pedidos que os clientes fazem (ou seja, quantos clientes fizeram apenas 1 pedido, quantos fizeram apenas 2, quantos apenas 3, etc.)
# 3.	Quais são os 20 produtos comprados com mais frequência? Exiba os IDs e nomes.

# %% [markdown]
# ### [B1] Diferenças nas quartas e sábados em `'order_hour_of_day'`. Crie gráficos de barras para ambos os dias e descreva as diferenças.

# %%
wed = df_orders[df_orders['order_dow'] == 3]
wed_per_hour = wed['order_hour_of_day'].value_counts().sort_index()

# %%
sat = df_orders[df_orders['order_dow'] == 6]
sat_per_hour = sat['order_hour_of_day'].value_counts().sort_index()

# %%
plt.figure(figsize=(12, 6))
wed_per_hour.plot(kind='bar', alpha=0.7, label='Wednesday', color='red')
sat_per_hour.plot(kind='bar', alpha=0.7, label='Saturday', color='blue')
plt.xlabel('Day hour')
plt.ylabel('Number of orders')
plt.title('Orders per hour: Wednesday vs Saturday')
plt.legend()
plt.show()

# %%
wed_top_3 = wed_per_hour.nlargest(3)
print('Horários com mais pedidos na quarta-feira:')
print(wed_top_3)
print()
sat_top_3 = sat_per_hour.nlargest(3)
print('Horários com mais pedidos no sábado:')
print(sat_top_3)
# Out:
# Horários com mais pedidos na quarta-feira:
# 15    5163
# 10    5026
# 11    5004
# Name: order_hour_of_day, dtype: int64
#
# Horários com mais pedidos no sábado:
# 14    5375
# 13    5323
# 15    5188
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Na quarta-feira temos picos de compras entre 13 e 14h, o pico do sábado é às 15h. A maior discrepância entre os dois dias ocorre entre o meio-dia e as 14h, onde o volume de compras no sábado é maior.***
#
# *Fiz uso do .nlargest() acima apenas por curiosidade.*

# %% [markdown]
# ### [B2] Qual é a distribuição do número de pedidos por cliente?

# %%
df_orders_per_client = df_orders.groupby('user_id')['order_number'].size()
df_orders_per_client.value_counts()
# Out:
# 1     55355
# 2     36508
# 3     21548
# 4     13498
# 5      8778
# 6      6012
# 7      4240
# 8      3016
# 9      2153
# 10     1646
# 11     1308
# 12      948
# 13      701
# 14      514
# 15      437
# 16      263
# 17      184
# 18      121
# 19       85
# 20       52
# 22       23
# 21       22
# 23       19
# 24        3
# 25        1
# 26        1
# 28        1
# Name: order_number, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> Comentário do revisor v1: </b> <a class="tocSkip"></a>
#
# - oriento usar .count() ou .size() em vez de max() pois é a forma mais correta
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Alterei. Optei por .max() porque sabia que os pedidos eram sequenciais e não números aleatórios, mas entendi que a forma correta seria as opções que passou.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor V2: </b> <a class="tocSkip"></a>
#
# Correto
# </div>

# %%
plt.figure(figsize=(15, 6))
df_orders_per_client_limited = df_orders_per_client[df_orders_per_client <= 35]
df_orders_per_client_limited.value_counts().plot(kind='bar', ylabel='Number of orders', xlabel='Number of clients', title='Number of orders per client')
plt.xticks(rotation=90)
plt.yticks(range(0, 12500, 500))
plt.tight_layout()
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Agrupei todos os dados por cliente e peguei o maior número de pedido de cada cliente (funciona pois os pedidos são sequenciais). Ao usar value_counts() extraí quantos pedidos cada cliente fez.***
#
# ***Limitei a quantidade de dados no gráfico e editei o range do eixo y para melhor visualização.***

# %% [markdown]
# ### [B3] Quais são os 20 produtos mais populares? Exiba os IDs e nomes.

# %%
top_20_products = df_order_products['product_id'].value_counts().head(20)

# %%
df_top_20_products = top_20_products.reset_index()
df_top_20_products.columns = ['product_id', 'count']
popular_products_names = df_top_20_products.merge(df_products, on='product_id')
display(popular_products_names[['product_id', 'count', 'product_name']].head(20))
# Out:
#     product_id  count              product_name
# 0        24852  66050                    Banana
# 1        13176  53297    Bag of Organic Bananas
# 2        21137  37039      Organic Strawberries
# 3        21903  33971      Organic Baby Spinach
# 4        47209  29773      Organic Hass Avocado
# 5        47766  24689           Organic Avocado
# 6        47626  21495               Large Lemon
# 7        16797  20018              Strawberries
# 8        26209  19690                     Limes
# 9        27845  19600        Organic Whole Milk
# 10       27966  19197       Organic Raspberries
# 11       22935  15898      Organic Yellow Onion
# 12       24964  15292            Organic Garlic
# 13       45007  14584          Organic Zucchini
# 14       39275  13879       Organic Blueberries
# 15       49683  13675            Cucumber Kirby
# 16       28204  12544        Organic Fuji Apple
# 17        5876  12232             Organic Lemon
# 18        8277  11993  Apple Honeycrisp Organic
# ...

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Utilizei .value_counts() e .head() para definir o top 20 dos produtos e coloquei em uma variável (resultou em uma Series). Depois foi necessário transformar o objeto Series em DataFrame. Por último foi possível fazer o merge() com a coluna comum entre os dfs.***

# %% [markdown]
# # [C] Difícil (é necessário concluir pelo menos duas perguntas para passar)
#
# 1.	Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?
# 2.	Quais são os 20 principais itens incluídos mais frequentemente em pedidos repetidos? Exiba os IDs e nomes.
# 3.	Para cada produto, qual parcela de seus pedidos são repetidos? Crie uma tabela com colunas de ID e nome do produto e a proporção de pedidos repetidos.
# 4.	Para cada cliente, qual proporção de todos os seus pedidos são repetidos?
# 5.	Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros? Exiba o ID do produto, nome e o número de vezes que ele foi o primeiro a ser adicionado a um carrinho.

# %% [markdown]
# ### [C1] Quantos itens as pessoas normalmente compram em um pedido? Como fica a distribuição?

# %%
items_per_order = df_order_products.groupby('order_id')['product_id'].count()
print(items_per_order.median())
# Out:
# 8.0

# %%
items_per_order.value_counts()
# Out:
# 5      31923
# 6      31698
# 4      31054
# 7      30822
# 3      29046
#        ...
# 80         1
# 87         1
# 85         1
# 72         1
# 127        1
# Name: product_id, Length: 90, dtype: int64

# %%
plt.figure(figsize=(12, 6))
items_per_order_limited = items_per_order[items_per_order <= 20]
items_per_order_limited.value_counts().sort_index().plot(kind='bar', xlabel='Item per order', 
                     ylabel='Frequency', title='Distribution of item per order')
plt.show()

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Normalmente as pessoas compram 8 itens. Usei median() porque é mais eficaz para distribuições assimétricas, pois não é influenciada por valores extremos (pedidos muito grandes), representando melhor o comportamento típico dos clientes. Foi ainda usado limitador para melhor visualização.***

# %% [markdown]
# ### [C2] Quais são os 20 principais itens incluídos com mais frequência em pedidos repetidos? Exiba os IDs e nomes.

# %%
df_order_repeat_products = df_order_products[df_order_products['reordered'] == 1]

# %%
top_20_repeat_products = df_order_repeat_products['product_id'].value_counts().head(20)

# %%
top_20_repeat_products = top_20_repeat_products.reset_index()
top_20_repeat_products.columns = ['product_id', 'frequency']

# %%
top_20_repeat_products.merge(df_products[['product_id', 'product_name']], on='product_id', how='left')
# Out:
#     product_id  frequency              product_name
# 0        24852      55763                    Banana
# 1        13176      44450    Bag of Organic Bananas
# 2        21137      28639      Organic Strawberries
# 3        21903      26233      Organic Baby Spinach
# 4        47209      23629      Organic Hass Avocado
# 5        47766      18743           Organic Avocado
# 6        27845      16251        Organic Whole Milk
# 7        47626      15044               Large Lemon
# 8        27966      14748       Organic Raspberries
# 9        16797      13945              Strawberries
# 10       26209      13327                     Limes
# 11       22935      11145      Organic Yellow Onion
# 12       24964      10411            Organic Garlic
# 13       45007      10076          Organic Zucchini
# 14       49683       9538            Cucumber Kirby
# 15       28204       8989        Organic Fuji Apple
# 16        8277       8836  Apple Honeycrisp Organic
# ...

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Filtrei a coluna reordered para manter apenas produtos repetidos, em cima dessa filtragem, contei quantas vezes cada product_id aparece e selecionei apenas os 20 primeiros produtos da coluna product_id (já está ordenado pois value_counts retorna em ordem decrescente).***
#
# ***Por fim, converti a series em df e fiz o merge() com as colunas de interesse do df_products.***

# %% [markdown]
# ### [C3] Para cada produto, qual parcela de todos os pedidos dele são repetidos?

# %% [markdown]
# Escreva suas conclusões aqui

# %% [markdown]
# ### [C4] Para cada cliente, qual proporção de todos os seus pedidos são repetidos?

# %% [markdown]
# Escreva suas conclusões aqui

# %% [markdown]
# ### [C5] Quais são os 20 principais itens que as pessoas colocam nos carrinhos antes de todos os outros?

# %%
df_main_20_products_ordered = df_order_products[df_order_products['add_to_cart_order'] == 1]

# %%
top_20_first_items = df_main_20_products_ordered['product_id'].value_counts().head(20)

# %%
top_20_first_items = top_20_first_items.reset_index()
top_20_first_items.columns=['product_id', 'count']
top_20_first_items.merge(df_products[['product_id', 'product_name']], on='product_id', how='left')
# Out:
#     product_id  count                 product_name
# 0        24852  15562                       Banana
# 1        13176  11026       Bag of Organic Bananas
# 2        27845   4363           Organic Whole Milk
# 3        21137   3946         Organic Strawberries
# 4        47209   3390         Organic Hass Avocado
# 5        21903   3336         Organic Baby Spinach
# 6        47766   3044              Organic Avocado
# 7        19660   2336                 Spring Water
# 8        16797   2308                 Strawberries
# 9        27966   2024          Organic Raspberries
# 10       44632   1914   Sparkling Water Grapefruit
# 11       49235   1797          Organic Half & Half
# 12       47626   1737                  Large Lemon
# 13         196   1733                         Soda
# 14       38689   1397     Organic Reduced Fat Milk
# 15       26209   1370                        Limes
# 16       12341   1340                Hass Avocados
# ...

# %% [markdown]
# Escreva suas conclusões aqui
#
# ***Como resultado, temos o id do produto na 1ª coluna, a quantidade de vezes em que esse item é colocado primeiro no carrinho e por fim o nome do produto.***

# %% [markdown]
# # Conclusão geral do projeto:

# %% [markdown]
# ***Trabalhoso, mas interessante por trazer vários dos conceitos aprendidos.***
#
# ***Com muita frequência é difícil entender o que a tarefa pede.***
#
# ***Não acredito que minha lógica de pensamento esteja tão ruim e sim que as questões estejam má formuladas textualmente (p.ex., enunciado ambíguo).***

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário Geral do Revisor Final: </b> <a class="tocSkip"></a>
#
# Eu vou repassar seu feedback para a equipe responsável. Fico feliz que você achou interessante. Você vai certamente aprender bastante nos próximos projetos.
# </div>
